# %% [markdown]
# # This is the notebook of the project using the code from the Solow.py class to simulate an economy

# %% [markdown]
# Firstly, we initialise the class that can be found in the Model.py file (also in the Code folder)

# %%
from Solow import Solow
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %% [markdown]
# We then create a Solow class instance

# %%
solow = Solow(a=1/3, g=0, n=0, d=0.02, s=0.1, K_0=1, A_0=1, L_0=1)

# %% [markdown]
# Secondly, we run a simple simulation for 50 years

# %%
simulation = solow.simulate(50)
title = simulation[0]
dataset = simulation[1]
df = pd.DataFrame(dataset[1:], columns=dataset[0])
df.index.names = ['Year']
df.head(n=5)
# Out:
#         Output   Capital  TFP  Labour  Investment  Consumption  Depreciation  \
# Year
# 0     1.000000  1.000000    1       1    0.100000     0.900000      0.000000
# 1     1.025986  1.080000    1       1    0.102599     0.923387      0.021600
# 2     1.051019  1.160999    1       1    0.105102     0.945917      0.023220
# 3     1.075168  1.242880    1       1    0.107517     0.967651      0.024858
# 4     1.098494  1.325540    1       1    0.109849     0.988644      0.026511
#
#       Output Change  Capital Change  TFP Change  ...  Output / Capita  \
# Year                                             ...
# 0          0.000000        0.000000           0  ...         1.000000
# 1          0.025986        0.080000           0  ...         1.025986
# 2          0.025033        0.080999           0  ...         1.051019
# 3          0.024149        0.081882           0  ...         1.075168
# 4          0.023325        0.082659           0  ...         1.098494
#
#       Capital / Effective Labour  Capital / Capita  Investment / Capita  \
# Year
# 0                       0.100000          0.900000             0.000000
# 1                       1.080000          1.080000             0.102599
# 2                       1.160999          1.160999             0.105102
# 3                       1.242880          1.242880             0.107517
# 4                       1.325540          1.325540             0.109849
#
#       Consumption / Capita  Output / Capita Change  \
# Year
# 0                 0.000000                0.000000
# 1                 0.923387                0.025986
# 2                 0.945917                0.025033
# 3                 0.967651                0.024149
# 4                 0.988644                0.023325
#
#       Capital / Effective Labour Change  Capital / Capita Change  \
# Year
# 0                              0.000000                 0.000000
# 1                              0.080000                 0.080000
# 2                              0.080999                 0.080999
# 3                              0.081882                 0.081882
# 4                              0.082659                 0.082659
#
#       Investment / Capita Change  Consumption / Capita Change
# Year
# 0                            NaN                          NaN
# 1                       0.025986                          0.0
# 2                       0.025033                          0.0
# 3                       0.024149                          0.0
# 4                       0.023325                          0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# We can plot some of the data here:

# %%
pio.renderers.default = 'notebook' # Enables rendering the plot in VSCode
pd.options.plotting.backend = "plotly" # Enables to plot multiple lines in one window
df.plot(x=df.index, y=['Output', 'Depreciation', 'Saving'], title=title)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e57a1f267dc0> in <module>
#       1 pio.renderers.default = 'notebook' # Enables rendering the plot in VSCode
#       2 pd.options.plotting.backend = "plotly" # Enables to plot multiple lines in one window
# ----> 3 df.plot(x=df.index, y=['Output', 'Depreciation', 'Saving'], title=title)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     877         # when using another backend, get out of the way
#     878         if plot_backend.__name__ != "pandas.plotting._matplotlib":
# --> 879             return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     880
#     881         if kind not in self._all_kinds:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/__init__.py in plot(data_frame, kind, **kwargs)
#     100         return scatter(data_frame, **new_kwargs)
#     101     if kind == "line":
# --> 102         return line(data_frame, **kwargs)
#     103     if kind == "area":
#     104         return area(data_frame, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     250     a polyline mark in 2D space.
#     251     """
# --> 252     return make_figure(args=locals(), constructor=go.Scatter)
#     253
#     254
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1877     apply_default_cascade(args)
#    1878
# -> 1879     args = build_dataframe(args, constructor)
#    1880     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1881         args = process_dataframe_hierarchy(args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1397     # now that things have been prepped, we do the systematic rewriting of `args`
#    1398
# -> 1399     df_output, wide_id_vars = process_args_into_dataframe(
#    1400         args, wide_mode, var_name, value_name
#    1401     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1241
#    1242                 if length and len(argument) != length:
# -> 1243                     raise ValueError(
#    1244                         "All arguments should have the same length. "
#    1245                         "The length of argument `%s` is %d, whereas the "
#
# ValueError: All arguments should have the same length. The length of argument `y` is 3, whereas the length of  previously-processed arguments ['Year'] is 51
